# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# Load the CSV file
csv_file = '10_anime.csv'
df = pd.read_csv(csv_file)

# Define a function to scrape the image URL from MyAnimeList
def get_anime_image_url(anime_name):
    search_url = f"https://myanimelist.net/search/all?q={anime_name.replace(' ', '%20')}&cat=all"
    response = requests.get(search_url)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        result = soup.find('a', {'class': 'hoverinfo_trigger'})
        if result:
            anime_page_url = result['href']
            anime_response = requests.get(anime_page_url)
            if anime_response.status_code == 200:
                anime_soup = BeautifulSoup(anime_response.text, 'html.parser')
                image_tag = anime_soup.find('img', {'itemprop': 'image'})
                if image_tag:
                    return image_tag['data-src'] if 'data-src' in image_tag.attrs else image_tag['src']
    return None

# Add a new column for image URLs
df['image_url'] = df['name'].apply(get_anime_image_url)

# Save the updated CSV file
df.to_csv('images.csv', index=False)

print("Image URLs added to the CSV file.")
# Out:
# Image URLs added to the CSV file.

# %%
import pandas as pd
import aiohttp
import asyncio
from bs4 import BeautifulSoup
import nest_asyncio
import time
from aiohttp import ClientTimeout

nest_asyncio.apply()

# Load the CSV file
csv_file = '10_anime.csv'
df = pd.read_csv(csv_file)

# Exponential backoff logic and error handling for fetching the image URL
async def get_anime_image_url(session, anime_name, retries=5, base_delay=1):
    search_url = f"https://myanimelist.net/search/all?q={anime_name.replace(' ', '%20')}&cat=all"
    timeout = ClientTimeout(total=15)  # Set a timeout for requests
    
    for attempt in range(retries):
        try:
            async with session.get(search_url, timeout=timeout) as response:
                if response.status == 200:
                    html = await response.text()
                    soup = BeautifulSoup(html, 'html.parser')
                    result = soup.find('a', {'class': 'hoverinfo_trigger'})
                    if result:
                        anime_page_url = result['href']
                        async with session.get(anime_page_url, timeout=timeout) as anime_response:
                            if anime_response.status == 200:
                                anime_html = await anime_response.text()
                                anime_soup = BeautifulSoup(anime_html, 'html.parser')
                                image_tag = anime_soup.find('img', {'itemprop': 'image'})
                                if image_tag:
                                    return image_tag['data-src'] if 'data-src' in image_tag.attrs else image_tag['src']
        except (aiohttp.ClientOSError, asyncio.TimeoutError, aiohttp.ClientResponseError) as e:
            delay = base_delay * (2 ** attempt)  # Exponential backoff
            print(f"Error fetching {anime_name}: {e}. Retrying in {delay} seconds...")
            await asyncio.sleep(delay)  # Exponential delay before retrying
    return None  # Return None if all retries fail

# Main asynchronous function to fetch image URLs with rate limiting
async def fetch_all_image_urls(anime_names, delay_between_requests=1):
    async with aiohttp.ClientSession() as session:
        tasks = []
        for anime_name in anime_names:
            tasks.append(get_anime_image_url(session, anime_name))
            await asyncio.sleep(delay_between_requests)  # Fixed delay between requests
        return await asyncio.gather(*tasks)

# Get all image URLs asynchronously with rate limiting
anime_names = df['name'].tolist()
image_urls = asyncio.run(fetch_all_image_urls(anime_names))
  
# Add the image URLs to the DataFrame
df['image_url'] = image_urls


# Save the updated CSV file
df.to_csv('fetch_with_images.csv', index=False)

print("Image URLs added to the CSV file.")
# Out:
# Image URLs added to the CSV file.

# %%
import pandas as pd
import aiohttp
import asyncio
from bs4 import BeautifulSoup
import nest_asyncio
import time
from aiohttp import ClientTimeout

nest_asyncio.apply()

# Load the CSV file
csv_file = '100_anime.csv'
df = pd.read_csv(csv_file)

# Exponential backoff logic and error handling for fetching the image URL
async def get_anime_image_url(session, anime_name, retries=5, base_delay=10):
    search_url = f"https://myanimelist.net/search/all?q={anime_name.replace(' ', '%20')}&cat=all"
    timeout = ClientTimeout(total=30)  # Increased timeout for slower connections
    
    for attempt in range(retries):
        try:
            async with session.get(search_url, timeout=timeout) as response:
                if response.status == 200:
                    html = await response.text()
                    soup = BeautifulSoup(html, 'html.parser')
                    result = soup.find('a', {'class': 'hoverinfo_trigger'})
                    if result:
                        anime_page_url = result['href']
                        async with session.get(anime_page_url, timeout=timeout) as anime_response:
                            if anime_response.status == 200:
                                anime_html = await anime_response.text()
                                anime_soup = BeautifulSoup(anime_html, 'html.parser')
                                image_tag = anime_soup.find('img', {'itemprop': 'image'})
                                if image_tag:
                                    return image_tag['data-src'] if 'data-src' in image_tag.attrs else image_tag['src']
                else:
                    print(f"Failed to retrieve search page for {anime_name}: Status {response.status}")
        except (aiohttp.ClientOSError, asyncio.TimeoutError, aiohttp.ClientResponseError) as e:
            delay = base_delay * (2 ** attempt)  # Exponential backoff
            print(f"Error fetching {anime_name}: {e}. Retrying in {delay} seconds...")
            await asyncio.sleep(delay)  # Exponential delay before retrying
    return None  # Return None if all retries fail

# Main asynchronous function to fetch image URLs with rate limiting
async def fetch_all_image_urls(anime_names, delay_between_requests=2):  # Increased delay to 2 seconds
    async with aiohttp.ClientSession() as session:
        tasks = []
        for anime_name in anime_names:
            tasks.append(get_anime_image_url(session, anime_name))
            await asyncio.sleep(delay_between_requests)  # Fixed delay between requests
        return await asyncio.gather(*tasks)

# Get all image URLs asynchronously with rate limiting
anime_names = df['name'].tolist()

# Try to fetch the image URLs
start_time = time.time()
image_urls = asyncio.run(fetch_all_image_urls(anime_names))
end_time = time.time()

# Add the image URLs to the DataFrame
df['image_url'] = image_urls

# Save the updated CSV file
df.to_csv('fetch_with_images.csv', index=False)

print(f"Image URLs added to the CSV file in {end_time - start_time:.2f} seconds.")
# Out:
# Error fetching Cross Fight B-Daman eS: . Retrying in 10 seconds...
# Error fetching Massugu ni Ikou. 2nd Season: . Retrying in 10 seconds...
# Error fetching Koutetsu Tenshi Kurumi Encore: . Retrying in 10 seconds...
# Error fetching eX-Driver the Movie: . Retrying in 10 seconds...
# Error fetching Kono Naka ni Hitori, Imouto ga Iru!: . Retrying in 10 seconds...
# Error fetching DNA²: . Retrying in 10 seconds...
# Error fetching Itoshi no Muco: . Retrying in 10 seconds...
# Error fetching Nintama Rantarou Movie: Ninjutsu Gakuen Zenin Shutsudou! no Dan: . Retrying in 10 seconds...
# Error fetching Myself ; Yourself Specials: . Retrying in 10 seconds...
# Error fetching Weiß Kreuz: . Retrying in 10 seconds...
# Error fetching Tsukumo: . Retrying in 10 seconds...
# Error fetching Slow Step: . Retrying in 10 seconds...
# Error fetching Toriko: Barbarian Ivy wo Hokaku Seyo!: . Retrying in 10 seconds...
# Error fetching Shin Koihime†Musou OVA: . Retrying in 10 seconds...
# Error fetching Spider Riders: Yomigaeru Taiyou: . Retrying in 10 seconds...
# Error fetching Saki Achiga-hen: Episode of Side-A - Kuro no Tanjoubi: . Retrying in 10 seconds...
# Error fetching Soratobu Yuureisen: . Retrying in 10 seconds...
# Error fetching Nagagutsu wo Haita Neko no Bouken: . Retrying in 10 seconds...
# Error fetching Mizugumo Monmon: . Retrying in 10 seconds...
# Error fetching Mayoi Neko Overrun! Specials: . Retrying in 10 seconds...
# Error fetching Shakugan no Shana: Friagne to Marianne no Naze Nani Shana! Nandemo Shitsumonbako!: . Retrying in 10 seconds...
# Error fetching Stella no Mahou: . Retrying in 10 seconds...
# Error fetching Koufuku Graffiti: . Retrying in 10 seconds...
# Error fetching Spoon Oba-san: . Retrying in 10 seconds...
# Error fetching Shinkon Gattai Godannar!!: . Retrying in 10 seconds...
# Error fetching Sakigake!! Otokojuku Movie: . Retrying in 10 seconds...
# Error fetching Sengoku Majin Goushougun: Toki no Etranger: . Retrying in 10 seconds...
# Error fetching Jikuu Boukenki Zentrix: . Retrying in 10 seconds...
# Error fetching Re:Zero kara Hajimeru Break Time: . Retrying in 10 seconds...
# Error fetching Saki Biyori Animation: . Retrying in 10 seconds...
# Error fetching Re-Kan!: . Retrying in 10 seconds...
# Error fetching Ranma ½: 1994 Music Calendar: . Retrying in 10 seconds...
# Error fetching Hurricane Live! 2033: . Retrying in 10 seconds...
# Error fetching Pucca: . Retrying in 10 seconds...
# Error fetching Phantom: Requiem for the Phantom Picture Drama: . Retrying in 10 seconds...
# Error fetching Sacred Seven: Shirogane no Tsubasa: . Retrying in 10 seconds...
# Error fetching Hareluya II Boy: . Retrying in 10 seconds...
# Error fetching Oz no Mahoutsukai (1986): . Retrying in 10 seconds...
# Error fetching Omishi Mahou Gekijou: Risky/Safety: . Retrying in 10 seconds...
# Error fetching Ginyuu Mokushiroku Meine Liebe Wieder: . Retrying in 10 seconds...
# Error fetching Nyanpire The Animation: . Retrying in 10 seconds...
# Error fetching Gegege no Kitarou (1971): . Retrying in 10 seconds...
# Error fetching Nagato Yuki-chan no Shoushitsu: Owarenai Natsuyasumi: . Retrying in 10 seconds...
# Error fetching Penguin Musume♥Heart: . Retrying in 10 seconds...
# Error fetching Majokko Tsukune-chan: . Retrying in 10 seconds...
# Error fetching Lady Lady!! (1988): . Retrying in 10 seconds...
# Error fetching Jack to Mame no Ki: . Retrying in 10 seconds...
# Error fetching Itsuka Tenma no Kuro Usagi: . Retrying in 10 seconds...
# Error fetching Oyayubi Hime Monogatari: . Retrying in 10 seconds...
# Error fetching Inazuma Eleven Go Recap: . Retrying in 10 seconds...
# Error fetching Ikkitousen: Shuugaku Toushi Keppuuroku: . Retrying in 10 seconds...
# Error fetching Battle Spirits: Shounen Toppa Bashin: . Retrying in 10 seconds...
# Error fetching Grenadier: Hohoemi no Senshi: . Retrying in 10 seconds...
# Error fetching Bakegyamon: . Retrying in 10 seconds...
# Error fetching God Mazinger: . Retrying in 10 seconds...
# Error fetching Girls und Panzer: Kore ga Hontou no Anzio-sen Desu! - Fushou - Akiyama Yukari no Sensha Kouza: . Retrying in 10 seconds...
# Error fetching Astarotte no Omocha! EX: . Retrying in 10 seconds...
# Error fetching Eiyuu Densetsu: Sora no Kiseki The Animation: . Retrying in 10 seconds...
# Error fetching Di Gi Charat Natsuyasumi Special: . Retrying in 10 seconds...
# Error fetching Days: . Retrying in 10 seconds...
# Error fetching Aiura: . Retrying in 10 seconds...
# Error fetching D.C. I&amp;II P.S.P. Re-Animated: . Retrying in 10 seconds...
# Error fetching 30-sai no Hoken Taiiku: . Retrying in 10 seconds...
# Error fetching Bananya: . Retrying in 10 seconds...
# Error fetching Azuki-chan: . Retrying in 10 seconds...
# Error fetching Yuu☆Yuu☆Hakusho Picture Drama: . Retrying in 10 seconds...
# Error fetching Working&#039;!! Announcement Specials: . Retrying in 10 seconds...
# Error fetching Konpeki no Kantai: . Retrying in 10 seconds...
# Error fetching Project BLUE Chikyuu SOS: . Retrying in 10 seconds...
# Error fetching Anime Sanjuushi: Aramis no Bouken: . Retrying in 10 seconds...
# Error fetching Kyou no Asuka Show: . Retrying in 10 seconds...
# Error fetching Machine-Doll wa Kizutsukanai Specials: . Retrying in 10 seconds...
# Error fetching Dragon Ball Z Movie 04: Super Saiyajin da Son Gokuu: . Retrying in 10 seconds...
# Error fetching Fresh Precure! Movie: Omocha no Kuni wa Himitsu ga Ippai!?: . Retrying in 10 seconds...
# Error fetching Majin Bone: . Retrying in 10 seconds...
# Error fetching Hamatora The Animation: Saishuukai Chokuzen! Mao ga Okuru Soushuuhen Special: . Retrying in 10 seconds...
# Error fetching Turn A Gundam II Movie: Moonlight Butterfly: . Retrying in 10 seconds...
# Error fetching Nurse Angel Ririka SOS: . Retrying in 10 seconds...
# Error fetching Cooking Papa: . Retrying in 10 seconds...
# Error fetching Koi to Senkyo to Chocolate: Ikenai Hazuki-sensei: . Retrying in 10 seconds...
# Error fetching Shiawase Sou no Okojo-san: . Retrying in 10 seconds...
# Error fetching DNA²: . Retrying in 20 seconds...
# Error fetching Koutetsu Tenshi Kurumi Encore: . Retrying in 20 seconds...
# Error fetching Mizugumo Monmon: . Retrying in 20 seconds...
# Error fetching Stella no Mahou: . Retrying in 20 seconds...
# Error fetching Spoon Oba-san: . Retrying in 20 seconds...
# Error fetching Shinkon Gattai Godannar!!: . Retrying in 20 seconds...
# Error fetching Pucca: . Retrying in 20 seconds...
# Error fetching Saki Biyori Animation: . Retrying in 20 seconds...
# Error fetching Sakigake!! Otokojuku Movie: . Retrying in 20 seconds...
# Error fetching Oz no Mahoutsukai (1986): . Retrying in 20 seconds...
# Error fetching Hareluya II Boy: . Retrying in 20 seconds...
# Error fetching Gegege no Kitarou (1971): . Retrying in 20 seconds...
# Error fetching Penguin Musume♥Heart: . Retrying in 20 seconds...
# Error fetching Ginyuu Mokushiroku Meine Liebe Wieder: . Retrying in 20 seconds...
# Error fetching Lady Lady!! (1988): . Retrying in 20 seconds...
# Error fetching Jack to Mame no Ki: . Retrying in 20 seconds...
# Error fetching Inazuma Eleven Go Recap: . Retrying in 20 seconds...
# Error fetching Oyayubi Hime Monogatari: . Retrying in 20 seconds...
# Error fetching Girls und Panzer: Kore ga Hontou no Anzio-sen Desu! - Fushou - Akiyama Yukari no Sensha Kouza: . Retrying in 20 seconds...
# Error fetching Eiyuu Densetsu: Sora no Kiseki The Animation: . Retrying in 20 seconds...
# Error fetching Astarotte no Omocha! EX: . Retrying in 20 seconds...
# Error fetching Days: . Retrying in 20 seconds...
# Error fetching Di Gi Charat Natsuyasumi Special: . Retrying in 20 seconds...
# Error fetching 30-sai no Hoken Taiiku: . Retrying in 20 seconds...
# Error fetching Slow Step: . Retrying in 20 seconds...
# Error fetching Nyanpire The Animation: . Retrying in 20 seconds...
# Error fetching Majokko Tsukune-chan: . Retrying in 20 seconds...
# Error fetching Nagato Yuki-chan no Shoushitsu: Owarenai Natsuyasumi: . Retrying in 20 seconds...
# Error fetching Phantom: Requiem for the Phantom Picture Drama: . Retrying in 20 seconds...
# Error fetching Working&#039;!! Announcement Specials: . Retrying in 20 seconds...
# Error fetching Itsuka Tenma no Kuro Usagi: . Retrying in 20 seconds...
# Error fetching Hurricane Live! 2033: . Retrying in 20 seconds...
# Error fetching Mayoi Neko Overrun! Specials: . Retrying in 20 seconds...
# Error fetching Grenadier: Hohoemi no Senshi: . Retrying in 20 seconds...
# Error fetching Battle Spirits: Shounen Toppa Bashin: . Retrying in 20 seconds...
# Error fetching Koufuku Graffiti: . Retrying in 20 seconds...
# Error fetching D.C. I&amp;II P.S.P. Re-Animated: . Retrying in 20 seconds...
# Error fetching Re:Zero kara Hajimeru Break Time: . Retrying in 20 seconds...
# Error fetching Re-Kan!: . Retrying in 20 seconds...
# Error fetching Spider Riders: Yomigaeru Taiyou: . Retrying in 20 seconds...
# Error fetching Jikuu Boukenki Zentrix: . Retrying in 20 seconds...
# Error fetching God Mazinger: . Retrying in 20 seconds...
# Error fetching Sengoku Majin Goushougun: Toki no Etranger: . Retrying in 20 seconds...
# Error fetching Ranma ½: 1994 Music Calendar: . Retrying in 20 seconds...
# Failed to retrieve search page for Dragon Ball Z Movie 04: Super Saiyajin da Son Gokuu: Status 405
# Failed to retrieve search page for Turn A Gundam II Movie: Moonlight Butterfly: Status 405
# Failed to retrieve search page for Dragon Ball Z Movie 04: Super Saiyajin da Son Gokuu: Status 405
# Failed to retrieve search page for Turn A Gundam II Movie: Moonlight Butterfly: Status 405
# Failed to retrieve search page for Dragon Ball Z Movie 04: Super Saiyajin da Son Gokuu: Status 405
# Failed to retrieve search page for Turn A Gundam II Movie: Moonlight Butterfly: Status 405
# Failed to retrieve search page for Dragon Ball Z Movie 04: Super Saiyajin da Son Gokuu: Status 405
# Failed to retrieve search page for Turn A Gundam II Movie: Moonlight Butterfly: Status 405
# Failed to retrieve search page for Koutetsu Tenshi Kurumi Encore: Status 405
# Failed to retrieve search page for DNA²: Status 405
# Failed to retrieve search page for Koutetsu Tenshi Kurumi Encore: Status 405
# Failed to retrieve search page for DNA²: Status 405
# Failed to retrieve search page for Koutetsu Tenshi Kurumi Encore: Status 405
# Failed to retrieve search page for DNA²: Status 405
# Failed to retrieve search page for Jack to Mame no Ki: Status 405
# Failed to retrieve search page for Shinkon Gattai Godannar!!: Status 405
# Failed to retrieve search page for Saki Biyori Animation: Status 405
# Failed to retrieve search page for Lady Lady!! (1988): Status 405
# Failed to retrieve search page for Stella no Mahou: Status 405
# Failed to retrieve search page for Oyayubi Hime Monogatari: Status 405
# Failed to retrieve search page for Penguin Musume♥Heart: Status 405
# Failed to retrieve search page for God Mazinger: Status 405
# Failed to retrieve search page for Hareluya II Boy: Status 405
# Failed to retrieve search page for Sengoku Majin Goushougun: Toki no Etranger: Status 405
# Failed to retrieve search page for Ginyuu Mokushiroku Meine Liebe Wieder: Status 405
# Failed to retrieve search page for Jikuu Boukenki Zentrix: Status 405
# Failed to retrieve search page for Oz no Mahoutsukai (1986): Status 405
# Failed to retrieve search page for Spoon Oba-san: Status 405
# Failed to retrieve search page for Eiyuu Densetsu: Sora no Kiseki The Animation: Status 405
# Failed to retrieve search page for Mizugumo Monmon: Status 405
# Failed to retrieve search page for Jack to Mame no Ki: Status 405
# Failed to retrieve search page for Shinkon Gattai Godannar!!: Status 405
# Failed to retrieve search page for Saki Biyori Animation: Status 405
# Failed to retrieve search page for Lady Lady!! (1988): Status 405
# Failed to retrieve search page for Stella no Mahou: Status 405
# Failed to retrieve search page for Pucca: Status 405
# Failed to retrieve search page for Oyayubi Hime Monogatari: Status 405
# Failed to retrieve search page for Sakigake!! Otokojuku Movie: Status 405
# Failed to retrieve search page for Penguin Musume♥Heart: Status 405
# Failed to retrieve search page for Girls und Panzer: Kore ga Hontou no Anzio-sen Desu! - Fushou - Akiyama Yukari no Sensha Kouza: Status 405
# Failed to retrieve search page for Sengoku Majin Goushougun: Toki no Etranger: Status 405
# Failed to retrieve search page for God Mazinger: Status 405
# Failed to retrieve search page for Hareluya II Boy: Status 405
# Failed to retrieve search page for Jack to Mame no Ki: Status 405
# Failed to retrieve search page for Gegege no Kitarou (1971): Status 405
# Failed to retrieve search page for Ginyuu Mokushiroku Meine Liebe Wieder: Status 405
# Failed to retrieve search page for Jikuu Boukenki Zentrix: Status 405
# Failed to retrieve search page for Stella no Mahou: Status 405
# Failed to retrieve search page for Saki Biyori Animation: Status 405
# Failed to retrieve search page for Shinkon Gattai Godannar!!: Status 405
# Failed to retrieve search page for Lady Lady!! (1988): Status 405
# Failed to retrieve search page for Spoon Oba-san: Status 405
# Failed to retrieve search page for Oz no Mahoutsukai (1986): Status 405
# Failed to retrieve search page for Re:Zero kara Hajimeru Break Time: Status 405
# Failed to retrieve search page for Inazuma Eleven Go Recap: Status 405
# Failed to retrieve search page for Working&#039;!! Announcement Specials: Status 405
# Failed to retrieve search page for Eiyuu Densetsu: Sora no Kiseki The Animation: Status 405
# Failed to retrieve search page for Nyanpire The Animation: Status 405
# Failed to retrieve search page for Battle Spirits: Shounen Toppa Bashin: Status 405
# Failed to retrieve search page for Mizugumo Monmon: Status 405
# Failed to retrieve search page for Astarotte no Omocha! EX: Status 405
# Failed to retrieve search page for Mayoi Neko Overrun! Specials: Status 405
# Failed to retrieve search page for Grenadier: Hohoemi no Senshi: Status 405
# Failed to retrieve search page for Nagato Yuki-chan no Shoushitsu: Owarenai Natsuyasumi: Status 405
# Failed to retrieve search page for Pucca: Status 405
# Failed to retrieve search page for Hurricane Live! 2033: Status 405
# Failed to retrieve search page for 30-sai no Hoken Taiiku: Status 405
# Failed to retrieve search page for Itsuka Tenma no Kuro Usagi: Status 405
# Failed to retrieve search page for D.C. I&amp;II P.S.P. Re-Animated: Status 405
# Failed to retrieve search page for Koufuku Graffiti: Status 405
# Failed to retrieve search page for Re-Kan!: Status 405
# Failed to retrieve search page for Days: Status 405
# Failed to retrieve search page for Ranma ½: 1994 Music Calendar: Status 405
# Failed to retrieve search page for Oyayubi Hime Monogatari: Status 405
# Failed to retrieve search page for Penguin Musume♥Heart: Status 405
# Failed to retrieve search page for Re:Zero kara Hajimeru Break Time: Status 405
# Failed to retrieve search page for Working&#039;!! Announcement Specials: Status 405
# Failed to retrieve search page for Sengoku Majin Goushougun: Toki no Etranger: Status 405
# Failed to retrieve search page for Nyanpire The Animation: Status 405
# Failed to retrieve search page for Battle Spirits: Shounen Toppa Bashin: Status 405
# Failed to retrieve search page for Astarotte no Omocha! EX: Status 405
# Failed to retrieve search page for Mayoi Neko Overrun! Specials: Status 405
# Failed to retrieve search page for Grenadier: Hohoemi no Senshi: Status 405
# Failed to retrieve search page for God Mazinger: Status 405
# Failed to retrieve search page for Hurricane Live! 2033: Status 405
# Failed to retrieve search page for Hareluya II Boy: Status 405
# Failed to retrieve search page for Nagato Yuki-chan no Shoushitsu: Owarenai Natsuyasumi: Status 405
# Failed to retrieve search page for 30-sai no Hoken Taiiku: Status 405
# Failed to retrieve search page for Ginyuu Mokushiroku Meine Liebe Wieder: Status 405
# Failed to retrieve search page for Oz no Mahoutsukai (1986): Status 405
# Failed to retrieve search page for Jikuu Boukenki Zentrix: Status 405
# Failed to retrieve search page for Spoon Oba-san: Status 405
# Failed to retrieve search page for Itsuka Tenma no Kuro Usagi: Status 405
# Failed to retrieve search page for D.C. I&amp;II P.S.P. Re-Animated: Status 405
# Failed to retrieve search page for Koufuku Graffiti: Status 405
# Failed to retrieve search page for Re-Kan!: Status 405
# Failed to retrieve search page for Days: Status 405
# Failed to retrieve search page for Ranma ½: 1994 Music Calendar: Status 405
# Failed to retrieve search page for Sakigake!! Otokojuku Movie: Status 405
# Failed to retrieve search page for Eiyuu Densetsu: Sora no Kiseki The Animation: Status 405
# Failed to retrieve search page for Re:Zero kara Hajimeru Break Time: Status 405
# Failed to retrieve search page for Mizugumo Monmon: Status 405
# Failed to retrieve search page for Girls und Panzer: Kore ga Hontou no Anzio-sen Desu! - Fushou - Akiyama Yukari no Sensha Kouza: Status 405
# Failed to retrieve search page for Pucca: Status 405
# Failed to retrieve search page for Gegege no Kitarou (1971): Status 405
# Failed to retrieve search page for Nyanpire The Animation: Status 405
# Failed to retrieve search page for Working&#039;!! Announcement Specials: Status 405
# Failed to retrieve search page for Astarotte no Omocha! EX: Status 405
# Failed to retrieve search page for Battle Spirits: Shounen Toppa Bashin: Status 405
# Failed to retrieve search page for Grenadier: Hohoemi no Senshi: Status 405
# Failed to retrieve search page for Hurricane Live! 2033: Status 405
# Failed to retrieve search page for 30-sai no Hoken Taiiku: Status 405
# Failed to retrieve search page for Mayoi Neko Overrun! Specials: Status 405
# Failed to retrieve search page for Nagato Yuki-chan no Shoushitsu: Owarenai Natsuyasumi: Status 405
# Failed to retrieve search page for Itsuka Tenma no Kuro Usagi: Status 405
# Failed to retrieve search page for Days: Status 405
# Failed to retrieve search page for Re-Kan!: Status 405
# Failed to retrieve search page for Koufuku Graffiti: Status 405
# Failed to retrieve search page for D.C. I&amp;II P.S.P. Re-Animated: Status 405
# Failed to retrieve search page for Inazuma Eleven Go Recap: Status 405
# Failed to retrieve search page for Ranma ½: 1994 Music Calendar: Status 405
# Failed to retrieve search page for Sakigake!! Otokojuku Movie: Status 405
# Failed to retrieve search page for Slow Step: Status 405
# Failed to retrieve search page for Girls und Panzer: Kore ga Hontou no Anzio-sen Desu! - Fushou - Akiyama Yukari no Sensha Kouza: Status 405
# Failed to retrieve search page for Gegege no Kitarou (1971): Status 405
# Failed to retrieve search page for Slow Step: Status 405
# Failed to retrieve search page for Inazuma Eleven Go Recap: Status 405
# Failed to retrieve search page for Slow Step: Status 405
# Failed to retrieve search page for Phantom: Requiem for the Phantom Picture Drama: Status 405
# Failed to retrieve search page for Spider Riders: Yomigaeru Taiyou: Status 405
# Failed to retrieve search page for Majokko Tsukune-chan: Status 405
# Failed to retrieve search page for Phantom: Requiem for the Phantom Picture Drama: Status 405
# Failed to retrieve search page for Spider Riders: Yomigaeru Taiyou: Status 405
# Failed to retrieve search page for Majokko Tsukune-chan: Status 405
# Failed to retrieve search page for Phantom: Requiem for the Phantom Picture Drama: Status 405
# Failed to retrieve search page for Spider Riders: Yomigaeru Taiyou: Status 405
# Failed to retrieve search page for Majokko Tsukune-chan: Status 405
# Error fetching Di Gi Charat Natsuyasumi Special: . Retrying in 40 seconds...
# Failed to retrieve search page for Di Gi Charat Natsuyasumi Special: Status 405
# Failed to retrieve search page for Di Gi Charat Natsuyasumi Special: Status 405
# Image URLs added to the CSV file in 386.90 seconds.
