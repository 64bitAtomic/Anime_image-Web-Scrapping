# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# Load the CSV file
csv_file = '10_anime.csv'
df = pd.read_csv(csv_file)

# Define a function to scrape the image URL from MyAnimeList
def get_anime_image_url(anime_name):
    search_url = f"https://myanimelist.net/search/all?q={anime_name.replace(' ', '%20')}&cat=all"
    response = requests.get(search_url)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        result = soup.find('a', {'class': 'hoverinfo_trigger'})
        if result:
            anime_page_url = result['href']
            anime_response = requests.get(anime_page_url)
            if anime_response.status_code == 200:
                anime_soup = BeautifulSoup(anime_response.text, 'html.parser')
                image_tag = anime_soup.find('img', {'itemprop': 'image'})
                if image_tag:
                    return image_tag['data-src'] if 'data-src' in image_tag.attrs else image_tag['src']
    return None

# Add a new column for image URLs
df['image_url'] = df['name'].apply(get_anime_image_url)

# Save the updated CSV file
df.to_csv('images.csv', index=False)

print("Image URLs added to the CSV file.")
# Out:
# Image URLs added to the CSV file.

# %%
import pandas as pd
import aiohttp
import asyncio
from bs4 import BeautifulSoup
import nest_asyncio
import time
from aiohttp import ClientTimeout

nest_asyncio.apply()

# Load the CSV file
csv_file = '10_anime.csv'
df = pd.read_csv(csv_file)

# Exponential backoff logic and error handling for fetching the image URL
async def get_anime_image_url(session, anime_name, retries=5, base_delay=1):
    search_url = f"https://myanimelist.net/search/all?q={anime_name.replace(' ', '%20')}&cat=all"
    timeout = ClientTimeout(total=15)  # Set a timeout for requests
    
    for attempt in range(retries):
        try:
            async with session.get(search_url, timeout=timeout) as response:
                if response.status == 200:
                    html = await response.text()
                    soup = BeautifulSoup(html, 'html.parser')
                    result = soup.find('a', {'class': 'hoverinfo_trigger'})
                    if result:
                        anime_page_url = result['href']
                        async with session.get(anime_page_url, timeout=timeout) as anime_response:
                            if anime_response.status == 200:
                                anime_html = await anime_response.text()
                                anime_soup = BeautifulSoup(anime_html, 'html.parser')
                                image_tag = anime_soup.find('img', {'itemprop': 'image'})
                                if image_tag:
                                    return image_tag['data-src'] if 'data-src' in image_tag.attrs else image_tag['src']
        except (aiohttp.ClientOSError, asyncio.TimeoutError, aiohttp.ClientResponseError) as e:
            delay = base_delay * (2 ** attempt)  # Exponential backoff
            print(f"Error fetching {anime_name}: {e}. Retrying in {delay} seconds...")
            await asyncio.sleep(delay)  # Exponential delay before retrying
    return None  # Return None if all retries fail

# Main asynchronous function to fetch image URLs with rate limiting
async def fetch_all_image_urls(anime_names, delay_between_requests=1):
    async with aiohttp.ClientSession() as session:
        tasks = []
        for anime_name in anime_names:
            tasks.append(get_anime_image_url(session, anime_name))
            await asyncio.sleep(delay_between_requests)  # Fixed delay between requests
        return await asyncio.gather(*tasks)

# Get all image URLs asynchronously with rate limiting
anime_names = df['name'].tolist()
image_urls = asyncio.run(fetch_all_image_urls(anime_names))
  
# Add the image URLs to the DataFrame
df['image_url'] = image_urls


# Save the updated CSV file
df.to_csv('fetch_with_images.csv', index=False)

print("Image URLs added to the CSV file.")
# Out:
# Image URLs added to the CSV file.

# %%
import pandas as pd
import aiohttp
import asyncio
from bs4 import BeautifulSoup
import nest_asyncio
import time
from aiohttp import ClientTimeout

nest_asyncio.apply()

# Load the CSV file
csv_file = '100_anime.csv'
df = pd.read_csv(csv_file)

# Exponential backoff logic and error handling for fetching the image URL
async def get_anime_image_url(session, anime_name, retries=5, base_delay=10):
    search_url = f"https://myanimelist.net/search/all?q={anime_name.replace(' ', '%20')}&cat=all"
    timeout = ClientTimeout(total=30)  # Increased timeout for slower connections
    
    for attempt in range(retries):
        try:
            async with session.get(search_url, timeout=timeout) as response:
                if response.status == 200:
                    html = await response.text()
                    soup = BeautifulSoup(html, 'html.parser')
                    result = soup.find('a', {'class': 'hoverinfo_trigger'})
                    if result:
                        anime_page_url = result['href']
                        async with session.get(anime_page_url, timeout=timeout) as anime_response:
                            if anime_response.status == 200:
                                anime_html = await anime_response.text()
                                anime_soup = BeautifulSoup(anime_html, 'html.parser')
                                image_tag = anime_soup.find('img', {'itemprop': 'image'})
                                if image_tag:
                                    return image_tag['data-src'] if 'data-src' in image_tag.attrs else image_tag['src']
                else:
                    print(f"Failed to retrieve search page for {anime_name}: Status {response.status}")
        except (aiohttp.ClientOSError, asyncio.TimeoutError, aiohttp.ClientResponseError) as e:
            delay = base_delay * (2 ** attempt)  # Exponential backoff
            print(f"Error fetching {anime_name}: {e}. Retrying in {delay} seconds...")
            await asyncio.sleep(delay)  # Exponential delay before retrying
    return None  # Return None if all retries fail

# Main asynchronous function to fetch image URLs with rate limiting
async def fetch_all_image_urls(anime_names, delay_between_requests=2):  # Increased delay to 2 seconds
    async with aiohttp.ClientSession() as session:
        tasks = []
        for anime_name in anime_names:
            tasks.append(get_anime_image_url(session, anime_name))
            await asyncio.sleep(delay_between_requests)  # Fixed delay between requests
        return await asyncio.gather(*tasks)

# Get all image URLs asynchronously with rate limiting
anime_names = df['name'].tolist()

# Try to fetch the image URLs
start_time = time.time()
image_urls = asyncio.run(fetch_all_image_urls(anime_names))
end_time = time.time()

# Add the image URLs to the DataFrame
df['image_url'] = image_urls

# Save the updated CSV file
df.to_csv('fetch_with_images.csv', index=False)

print(f"Image URLs added to the CSV file in {end_time - start_time:.2f} seconds.")
# Out:
# Error fetching Nenga no Kizuna: . Retrying in 10 seconds...
# Error fetching SD Gundam Gaiden: . Retrying in 10 seconds...
# Error fetching Beast Saga: . Retrying in 10 seconds...
# Error fetching Kaichuu!: . Retrying in 10 seconds...
# Error fetching Kikyuu: . Retrying in 10 seconds...
# Error fetching Ten no Kawa: . Retrying in 10 seconds...
# Error fetching Rolling☆Girls: Chibi☆Rolling☆Girls Korokoro Gekijou: . Retrying in 10 seconds...
# Error fetching Kiitarou Shounen no Youkai Enikki: . Retrying in 10 seconds...
# Error fetching Psycho Diver: Mashou Bosatsu: . Retrying in 10 seconds...
# Error fetching Pankunchi: . Retrying in 10 seconds...
# Error fetching Hashire!: . Retrying in 10 seconds...
# Error fetching Kakko Kawaii Sengen!: . Retrying in 10 seconds...
# Error fetching Mujigen Hunter Fandora: . Retrying in 10 seconds...
# Error fetching MAPS: . Retrying in 10 seconds...
# Error fetching Juuza Engi: Engetsu Sangokuden - Gaiden Youzhou Genya: . Retrying in 10 seconds...
# Error fetching Juusenki L-Gaim II: Farewell My Lovely + Pentagona Doors: . Retrying in 10 seconds...
# Error fetching Handsome Girl: . Retrying in 10 seconds...
# Error fetching Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu
# Failed to retrieve search page for Hatsune Miku: Hiyashite Narasou Okashi no Ii Oto: Status 405
# Failed to retrieve search page for Mahou Shoujo Sonico★Magica: Status 405
# Failed to retrieve search page for Shounen Ashibe: Go! Go! Goma-chan: Status 405
# Failed to retrieve search page for Kotatsu Neko (ONA): Status 405
# Failed to retrieve search page for Boku no Imouto wa &quot;Osaka Okan&quot;: Uchi no Oniichan wa Tokyo Rule: Status 405
# Failed to retrieve search page for Hashire!: Status 405
# Failed to retrieve search page for Koi Koi 7: Status 405
# Failed to retrieve search page for Kamisama Dolls Specials: Status 405
# Failed to retrieve search page for Nexus: Status 405
# Failed to retrieve search page for Koi Koi 7 Specials: Status 405
# Failed to retrieve search page for Akai Hayate: Status 405
# Failed to retrieve search page for Gakuen Handsome: Legend of Sexy: Status 405
# Failed to retrieve search page for Nenga no Kizuna: Status 405
# Failed to retrieve search page for Little Nemo Pilot (1987): Status 405
# Failed to retrieve search page for Garo: Guren no Tsuki: Status 405
# Failed to retrieve search page for Seirei Tsukai: Status 405
# Failed to retrieve search page for Dream Creator feat. GUMI: Status 405
# Failed to retrieve search page for Youkai Ningen Bem (2006): Status 405
# Failed to retrieve search page for Magma Taishi: Status 405
# Failed to retrieve search page for Boku no Imouto wa &quot;Osaka Okan&quot;: Status 405
# Failed to retrieve search page for Youkoso Jitsuryoku Shijou Shugi no Kyoushitsu e: Status 405
# Failed to retrieve search page for Kiitarou Shounen no Youkai Enikki: Status 405
# Failed to retrieve search page for Bab Mook Ja: Status 405
# Failed to retrieve search page for Tactical Roar Special: Status 405
# Failed to retrieve search page for DragonBlade: Status 405
# Failed to retrieve search page for Pankunchi: Status 405
# Failed to retrieve search page for Marie &amp; Gali Episode Zero: Status 405
# Failed to retrieve search page for Flying Witch Petit: Status 405
# Failed to retrieve search page for Mahou no Tenshi Creamy Mami: Zutto Kitto Motto: Status 405
# Failed to retrieve search page for Youchien Senshi: Hanamaru Girls: Status 405
# Failed to retrieve search page for Donyatsu Specials: Status 405
# Failed to retrieve search page for Rolling☆Girls: Chibi☆Rolling☆Girls Korokoro Gekijou: Status 405
# Failed to retrieve search page for Handsome Girl: Status 405
# Failed to retrieve search page for Ninja Mono: Status 405
# Failed to retrieve search page for Yuki Terai: Status 405
# Failed to retrieve search page for Beast Saga: Status 405
# Failed to retrieve search page for Kumo to Tulip: Status 405
# Failed to retrieve search page for Fire Emblem: Status 405
# Failed to retrieve search page for Dark Side Cat: Status 405
# Failed to retrieve search page for Neko nanka Yondemo Konai.: Status 405
# Failed to retrieve search page for Si Ling Bianma: Zhi Shijie Caozong Zhe: Status 405
# Failed to retrieve search page for MAPS: Status 405
# Failed to retrieve search page for SD Gundam Gaiden: Status 405
# Failed to retrieve search page for Space Station No.9: Status 405
# Failed to retrieve search page for Yoshino no Hime: Status 405
# Failed to retrieve search page for Dai Yamato Zero-gou: Status 405
# Failed to retrieve search page for Fake Doll: Status 405
# Failed to retrieve search page for Namida no Tsubomi: Status 405
# Failed to retrieve search page for Wake Up, Girl Zoo! Miyagi PR de Go!: Status 405
# Image URLs added to the CSV file in 496.29 seconds.
