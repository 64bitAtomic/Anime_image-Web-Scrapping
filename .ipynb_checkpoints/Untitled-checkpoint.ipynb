# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# Load the CSV file
csv_file = '10_anime.csv'
df = pd.read_csv(csv_file)

# Define a function to scrape the image URL from MyAnimeList
def get_anime_image_url(anime_name):
    search_url = f"https://myanimelist.net/search/all?q={anime_name.replace(' ', '%20')}&cat=all"
    response = requests.get(search_url)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        result = soup.find('a', {'class': 'hoverinfo_trigger'})
        if result:
            anime_page_url = result['href']
            anime_response = requests.get(anime_page_url)
            if anime_response.status_code == 200:
                anime_soup = BeautifulSoup(anime_response.text, 'html.parser')
                image_tag = anime_soup.find('img', {'itemprop': 'image'})
                if image_tag:
                    return image_tag['data-src'] if 'data-src' in image_tag.attrs else image_tag['src']
    return None

# Add a new column for image URLs
df['image_url'] = df['name'].apply(get_anime_image_url)

# Save the updated CSV file
df.to_csv('images.csv', index=False)

print("Image URLs added to the CSV file.")
# Out:
# Image URLs added to the CSV file.

# %%
import pandas as pd
import aiohttp
import asyncio
from bs4 import BeautifulSoup
import nest_asyncio
import time
from aiohttp import ClientTimeout

nest_asyncio.apply()

# Load the CSV file
csv_file = '10_anime.csv'
df = pd.read_csv(csv_file)

# Exponential backoff logic and error handling for fetching the image URL
async def get_anime_image_url(session, anime_name, retries=5, base_delay=1):
    search_url = f"https://myanimelist.net/search/all?q={anime_name.replace(' ', '%20')}&cat=all"
    timeout = ClientTimeout(total=15)  # Set a timeout for requests
    
    for attempt in range(retries):
        try:
            async with session.get(search_url, timeout=timeout) as response:
                if response.status == 200:
                    html = await response.text()
                    soup = BeautifulSoup(html, 'html.parser')
                    result = soup.find('a', {'class': 'hoverinfo_trigger'})
                    if result:
                        anime_page_url = result['href']
                        async with session.get(anime_page_url, timeout=timeout) as anime_response:
                            if anime_response.status == 200:
                                anime_html = await anime_response.text()
                                anime_soup = BeautifulSoup(anime_html, 'html.parser')
                                image_tag = anime_soup.find('img', {'itemprop': 'image'})
                                if image_tag:
                                    return image_tag['data-src'] if 'data-src' in image_tag.attrs else image_tag['src']
        except (aiohttp.ClientOSError, asyncio.TimeoutError, aiohttp.ClientResponseError) as e:
            delay = base_delay * (2 ** attempt)  # Exponential backoff
            print(f"Error fetching {anime_name}: {e}. Retrying in {delay} seconds...")
            await asyncio.sleep(delay)  # Exponential delay before retrying
    return None  # Return None if all retries fail

# Main asynchronous function to fetch image URLs with rate limiting
async def fetch_all_image_urls(anime_names, delay_between_requests=1):
    async with aiohttp.ClientSession() as session:
        tasks = []
        for anime_name in anime_names:
            tasks.append(get_anime_image_url(session, anime_name))
            await asyncio.sleep(delay_between_requests)  # Fixed delay between requests
        return await asyncio.gather(*tasks)

# Get all image URLs asynchronously with rate limiting
anime_names = df['name'].tolist()
image_urls = asyncio.run(fetch_all_image_urls(anime_names))
  
# Add the image URLs to the DataFrame
df['image_url'] = image_urls


# Save the updated CSV file
df.to_csv('fetch_with_images.csv', index=False)

print("Image URLs added to the CSV file.")
# Out:
# Image URLs added to the CSV file.

# %%
import pandas as pd
import aiohttp
import asyncio
from bs4 import BeautifulSoup
import nest_asyncio
import time
from aiohttp import ClientTimeout

nest_asyncio.apply()

# Load the CSV file
csv_file = '100_anime.csv'
df = pd.read_csv(csv_file)

# Exponential backoff logic and error handling for fetching the image URL
async def get_anime_image_url(session, anime_name, retries=5, base_delay=10):
    search_url = f"https://myanimelist.net/search/all?q={anime_name.replace(' ', '%20')}&cat=all"
    timeout = ClientTimeout(total=30)  # Increased timeout for slower connections
    
    for attempt in range(retries):
        try:
            async with session.get(search_url, timeout=timeout) as response:
                if response.status == 200:
                    html = await response.text()
                    soup = BeautifulSoup(html, 'html.parser')
                    result = soup.find('a', {'class': 'hoverinfo_trigger'})
                    if result:
                        anime_page_url = result['href']
                        async with session.get(anime_page_url, timeout=timeout) as anime_response:
                            if anime_response.status == 200:
                                anime_html = await anime_response.text()
                                anime_soup = BeautifulSoup(anime_html, 'html.parser')
                                image_tag = anime_soup.find('img', {'itemprop': 'image'})
                                if image_tag:
                                    return image_tag['data-src'] if 'data-src' in image_tag.attrs else image_tag['src']
                else:
                    print(f"Failed to retrieve search page for {anime_name}: Status {response.status}")
        except (aiohttp.ClientOSError, asyncio.TimeoutError, aiohttp.ClientResponseError) as e:
            delay = base_delay * (2 ** attempt)  # Exponential backoff
            print(f"Error fetching {anime_name}: {e}. Retrying in {delay} seconds...")
            await asyncio.sleep(delay)  # Exponential delay before retrying
    return None  # Return None if all retries fail

# Main asynchronous function to fetch image URLs with rate limiting
async def fetch_all_image_urls(anime_names, delay_between_requests=2):  # Increased delay to 2 seconds
    async with aiohttp.ClientSession() as session:
        tasks = []
        for anime_name in anime_names:
            tasks.append(get_anime_image_url(session, anime_name))
            await asyncio.sleep(delay_between_requests)  # Fixed delay between requests
        return await asyncio.gather(*tasks)

# Get all image URLs asynchronously with rate limiting
anime_names = df['name'].tolist()

# Try to fetch the image URLs
start_time = time.time()
image_urls = asyncio.run(fetch_all_image_urls(anime_names))
end_time = time.time()

# Add the image URLs to the DataFrame
df['image_url'] = image_urls
 
# Save the updated CSV file
df.to_csv('fetch_with_images.csv', index=False)

print(f"Image URLs added to the CSV file in {end_time - start_time:.2f} seconds.")
# Out:
# Error fetching Original C-V-P Momoko: . Retrying in 10 seconds...
# Error fetching Battle Can²: . Retrying in 10 seconds...
# Error fetching Offside Girl: . Retrying in 10 seconds...
# Error fetching Tokineiro: . Retrying in 10 seconds...
# Error fetching Pico x CoCo x Chico: . Retrying in 10 seconds...
# Error fetching Heisei Jogakuen Kagai Lesson: . Retrying in 10 seconds...
# Error fetching Idol Kyousei Sousa: . Retrying in 10 seconds...
# Error fetching Kateikyoushi Bishounen Kari: . Retrying in 10 seconds...
# Error fetching Hitorijime My Hero: . Retrying in 10 seconds...
# Error fetching Hi Gekiga Ukiyoe Senya Ichiya: . Retrying in 10 seconds...
# Error fetching Advancer Tina: . Retrying in 10 seconds...
# Error fetching Fairy Forest Remi-chan: . Retrying in 10 seconds...
# Error fetching Kaguya-hime: Taketori Monogatari: . Retrying in 10 seconds...
# Error fetching Gin no Otoko: . Retrying in 10 seconds...
# Error fetching Classical Sex-Zone: . Retrying in 10 seconds...
# Error fetching Citrus: . Retrying in 10 seconds...
# Error fetching You Bishoujo Miruku-chan: . Retrying in 10 seconds...
# Error fetching Bishoujo Animerama: Manami no Michi Tono Sou Nyuu!?: . Retrying in 10 seconds...
# Error fetching Tsui no Sora: . Retrying in 10 seconds...
# Error fetching Rebiya: . Retrying in 10 seconds...
# Error fetching Joshidai: Ecchi Soudanshitsu: . Retrying in 10 seconds...
# Error fetching Under World: . Retrying in 10 seconds...
# Error fetching Tenshi no Habataki Jun: . Retrying in 10 seconds...
# Error fetching Super Erotic Anime: . Retrying in 10 seconds...
# Error fetching Silent Chaser Kagami: . Retrying in 10 seconds...
# Error fetching Shikkoku no Shaga The Animation: . Retrying in 10 seconds...
# Error fetching Mirai Choujuu Fobia: . Retrying in 10 seconds...
# Error fetching Sakura no Mori: . Retrying in 10 seconds...
# Error fetching Sagurare Otome The Animation: . Retrying in 10 seconds...
# Error fetching Pink no Curtain: . Retrying in 10 seconds...
# Error fetching Boku no Pico: . Retrying in 10 seconds...
# Error fetching Henbou Moral Hazard: . Retrying in 10 seconds...
# Error fetching Original Video Romance Animation: . Retrying in 10 seconds...
# Error fetching Youbi Masochist Animation: . Retrying in 10 seconds...
# Error fetching Yayoi: . Retrying in 10 seconds...
# Error fetching Nudl Nude 2: . Retrying in 10 seconds...
# Error fetching Maid Meshimase: . Retrying in 10 seconds...
# Error fetching Misato-chan no Yume Nikki: . Retrying in 10 seconds...
# Error fetching Denki Musou Hana: . Retrying in 10 seconds...
# Error fetching Injuu Nerawareta Idol: . Retrying in 10 seconds...
# Error fetching Kyuukyoku no Chef wa Oishinbo Papa: . Retrying in 10 seconds...
# Error fetching Docchi mo Maid: . Retrying in 10 seconds...
# Error fetching Bishoujo Animerama: Miyuki-chan SOS-H Shichauzo: . Retrying in 10 seconds...
# Error fetching Shirouto Kurabu: . Retrying in 10 seconds...
# Error fetching G.T.R G-cup Teacher Rei: . Retrying in 10 seconds...
# Error fetching Under World: . Retrying in 20 seconds...
# Error fetching Original C-V-P Momoko: . Retrying in 20 seconds...
# Error fetching Sakura no Mori: . Retrying in 20 seconds...
# Error fetching Shirouto Kurabu: . Retrying in 20 seconds...
# Error fetching Injuu Nerawareta Idol: . Retrying in 20 seconds...
# Error fetching Hi Gekiga Ukiyoe Senya Ichiya: . Retrying in 20 seconds...
# Image URLs added to the CSV file in 306.97 seconds.
