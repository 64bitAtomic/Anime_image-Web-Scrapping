# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# Load the CSV file
csv_file = '10_anime.csv'
df = pd.read_csv(csv_file)

# Define a function to scrape the image URL from MyAnimeList
def get_anime_image_url(anime_name):
    search_url = f"https://myanimelist.net/search/all?q={anime_name.replace(' ', '%20')}&cat=all"
    response = requests.get(search_url)
    
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        result = soup.find('a', {'class': 'hoverinfo_trigger'})
        if result:
            anime_page_url = result['href']
            anime_response = requests.get(anime_page_url)
            if anime_response.status_code == 200:
                anime_soup = BeautifulSoup(anime_response.text, 'html.parser')
                image_tag = anime_soup.find('img', {'itemprop': 'image'})
                if image_tag:
                    return image_tag['data-src'] if 'data-src' in image_tag.attrs else image_tag['src']
    return None

# Add a new column for image URLs
df['image_url'] = df['name'].apply(get_anime_image_url)

# Save the updated CSV file
df.to_csv('images.csv', index=False)

print("Image URLs added to the CSV file.")
# Out:
# Image URLs added to the CSV file.

# %%
import pandas as pd
import aiohttp
import asyncio
from bs4 import BeautifulSoup
import nest_asyncio
import time
from aiohttp import ClientTimeout

nest_asyncio.apply()

# Load the CSV file
csv_file = '10_anime.csv'
df = pd.read_csv(csv_file)

# Exponential backoff logic and error handling for fetching the image URL
async def get_anime_image_url(session, anime_name, retries=5, base_delay=1):
    search_url = f"https://myanimelist.net/search/all?q={anime_name.replace(' ', '%20')}&cat=all"
    timeout = ClientTimeout(total=15)  # Set a timeout for requests
    
    for attempt in range(retries):
        try:
            async with session.get(search_url, timeout=timeout) as response:
                if response.status == 200:
                    html = await response.text()
                    soup = BeautifulSoup(html, 'html.parser')
                    result = soup.find('a', {'class': 'hoverinfo_trigger'})
                    if result:
                        anime_page_url = result['href']
                        async with session.get(anime_page_url, timeout=timeout) as anime_response:
                            if anime_response.status == 200:
                                anime_html = await anime_response.text()
                                anime_soup = BeautifulSoup(anime_html, 'html.parser')
                                image_tag = anime_soup.find('img', {'itemprop': 'image'})
                                if image_tag:
                                    return image_tag['data-src'] if 'data-src' in image_tag.attrs else image_tag['src']
        except (aiohttp.ClientOSError, asyncio.TimeoutError, aiohttp.ClientResponseError) as e:
            delay = base_delay * (2 ** attempt)  # Exponential backoff
            print(f"Error fetching {anime_name}: {e}. Retrying in {delay} seconds...")
            await asyncio.sleep(delay)  # Exponential delay before retrying
    return None  # Return None if all retries fail

# Main asynchronous function to fetch image URLs with rate limiting
async def fetch_all_image_urls(anime_names, delay_between_requests=1):
    async with aiohttp.ClientSession() as session:
        tasks = []
        for anime_name in anime_names:
            tasks.append(get_anime_image_url(session, anime_name))
            await asyncio.sleep(delay_between_requests)  # Fixed delay between requests
        return await asyncio.gather(*tasks)

# Get all image URLs asynchronously with rate limiting
anime_names = df['name'].tolist()
image_urls = asyncio.run(fetch_all_image_urls(anime_names))
  
# Add the image URLs to the DataFrame
df['image_url'] = image_urls


# Save the updated CSV file
df.to_csv('fetch_with_images.csv', index=False)

print("Image URLs added to the CSV file.")
# Out:
# Image URLs added to the CSV file.

# %%
import pandas as pd
import aiohttp
import asyncio
from bs4 import BeautifulSoup
import nest_asyncio
import time
from aiohttp import ClientTimeout

nest_asyncio.apply()

# Load the CSV file
csv_file = '100_anime.csv'
df = pd.read_csv(csv_file)

# Exponential backoff logic and error handling for fetching the image URL
async def get_anime_image_url(session, anime_name, retries=5, base_delay=10):
    search_url = f"https://myanimelist.net/search/all?q={anime_name.replace(' ', '%20')}&cat=all"
    timeout = ClientTimeout(total=30)  # Increased timeout for slower connections
    
    for attempt in range(retries):
        try:
            async with session.get(search_url, timeout=timeout) as response:
                if response.status == 200:
                    html = await response.text()
                    soup = BeautifulSoup(html, 'html.parser')
                    result = soup.find('a', {'class': 'hoverinfo_trigger'})
                    if result:
                        anime_page_url = result['href']
                        async with session.get(anime_page_url, timeout=timeout) as anime_response:
                            if anime_response.status == 200:
                                anime_html = await anime_response.text()
                                anime_soup = BeautifulSoup(anime_html, 'html.parser')
                                image_tag = anime_soup.find('img', {'itemprop': 'image'})
                                if image_tag:
                                    return image_tag['data-src'] if 'data-src' in image_tag.attrs else image_tag['src']
                else:
                    print(f"Failed to retrieve search page for {anime_name}: Status {response.status}")
        except (aiohttp.ClientOSError, asyncio.TimeoutError, aiohttp.ClientResponseError) as e:
            delay = base_delay * (2 ** attempt)  # Exponential backoff
            print(f"Error fetching {anime_name}: {e}. Retrying in {delay} seconds...")
            await asyncio.sleep(delay)  # Exponential delay before retrying
    return None  # Return None if all retries fail

# Main asynchronous function to fetch image URLs with rate limiting
async def fetch_all_image_urls(anime_names, delay_between_requests=2):  # Increased delay to 2 seconds
    async with aiohttp.ClientSession() as session:
        tasks = []
        for anime_name in anime_names:
            tasks.append(get_anime_image_url(session, anime_name))
            await asyncio.sleep(delay_between_requests)  # Fixed delay between requests
        return await asyncio.gather(*tasks)

# Get all image URLs asynchronously with rate limiting
anime_names = df['name'].tolist()

# Try to fetch the image URLs
start_time = time.time()
image_urls = asyncio.run(fetch_all_image_urls(anime_names))
end_time = time.time()

# Add the image URLs to the DataFrame
df['image_url'] = image_urls
 
# Save the updated CSV file
df.to_csv('fetch_with_images.csv', index=False)

print(f"Image URLs added to the CSV file in {end_time - start_time:.2f} seconds.")
# Out:
# Error fetching Spo-chan Taiketsu: Youkai Daikessen: . Retrying in 10 seconds...
# Error fetching Spring Stranger: . Retrying in 10 seconds...
# Error fetching Starlight Scramble Renai Kouhosei: . Retrying in 10 seconds...
# Error fetching Subarashii Sekai Ryokou: Alaska no Tabi &quot;Daigo Hyougaki&quot;: . Retrying in 10 seconds...
# Error fetching Sumiko (TV): . Retrying in 10 seconds...
# Error fetching Taiheiyou ni Kakeru Niji: . Retrying in 10 seconds...
# Error fetching Taeng-gu &amp; Ulasyong: . Retrying in 10 seconds...
# Error fetching Sumiko: . Retrying in 10 seconds...
# Error fetching Taekwon Dongja Maruchi Arachi: . Retrying in 10 seconds...
# Error fetching Taegeugsonyeon Huin Dogsuli: . Retrying in 10 seconds...
# Error fetching Stray Sheep: Poe no Chicchana Daibouken: . Retrying in 10 seconds...
# Error fetching Sukima no Kuni no Polta: . Retrying in 10 seconds...
# Failed to retrieve search page for Subarashii Sekai Ryokou: New York Tabi &quot;Computopia Seireki Nisennen no Monogatari&quot;: Status 405
# Failed to retrieve search page for Susume! Shinji-kun: Status 405
# Failed to retrieve search page for Taka no Tsume NEO Announcement Movie: Status 405
# Failed to retrieve search page for Sylvanian Families: Status 405
# Failed to retrieve search page for Talpy: Status 405
# Failed to retrieve search page for Stitch! Perfect Memory: Status 405
# Failed to retrieve search page for Sugai-kun to Kazoku Ishi The Movie: Status 405
# Failed to retrieve search page for Super Titans 15: Status 405
# Failed to retrieve search page for Sushi Azarashi: Status 405
# Failed to retrieve search page for Straw Byururu: Status 405
# Failed to retrieve search page for Tasukeai no Rekishi: Inochi Hoken no Hajimari: Status 405
# Failed to retrieve search page for Super Real Mahjong: Mahjong Battle Scramble - Konran-teki Sento Mahjong: Status 405
# Failed to retrieve search page for Subarashii Sekai Ryokou: New York Tabi &quot;Computopia Seireki Nisennen no Monogatari&quot;: Status 405
# Failed to retrieve search page for Taka no Tsume NEO Announcement Movie: Status 405
# Failed to retrieve search page for Sylvanian Families: Status 405
# Failed to retrieve search page for Talpy: Status 405
# Failed to retrieve search page for Stitch! Perfect Memory: Status 405
# Failed to retrieve search page for Sugai-kun to Kazoku Ishi The Movie: Status 405
# Failed to retrieve search page for Suisenzuki no Yokka: Status 405
# Failed to retrieve search page for Surf Side High-School: Status 405
# Failed to retrieve search page for Tanoshii Bunmeishi: Tetsu Monogatari: Status 405
# Failed to retrieve search page for Straw-saurus Neo: Status 405
# Failed to retrieve search page for Taabou no Ganbaru Sengen: Status 405
# Failed to retrieve search page for Sushi Azarashi: Status 405
# Failed to retrieve search page for Tamagotchi! Yume Kira Dream: Status 405
# Failed to retrieve search page for Tasukeai no Rekishi: Inochi Hoken no Hajimari: Status 405
# Failed to retrieve search page for Straw Byururu: Status 405
# Failed to retrieve search page for Tao Hua Yuan Ji: Status 405
# Failed to retrieve search page for Suisenzuki no Yokka: Status 405
# Failed to retrieve search page for Sue Cat: Status 405
# Failed to retrieve search page for Spy Gekimetsu: Status 405
# Failed to retrieve search page for Surf Side High-School: Status 405
# Failed to retrieve search page for Tam Mao Phieu Luu Ky Ta: Status 405
# Failed to retrieve search page for Takemoto Denki x Peeping Life: Status 405
# Failed to retrieve search page for Straw-saurus Neo: Status 405
# Failed to retrieve search page for Tanoshii Bunmeishi: Tetsu Monogatari: Status 405
# Failed to retrieve search page for Suijun Genten: Status 405
# Failed to retrieve search page for Taabou no Ganbaru Sengen: Status 405
# Failed to retrieve search page for Tamagotchi! Yume Kira Dream: Status 405
# Failed to retrieve search page for Starlight Scramble Renai Kouhosei: Status 405
# Failed to retrieve search page for Tatakae! Osper: Status 405
# Failed to retrieve search page for Taiman Blues: Shimizu Naoto-hen: Status 405
# Failed to retrieve search page for Sugar Bunnies Fleur: Status 405
# Failed to retrieve search page for Stone: Status 405
# Failed to retrieve search page for Tabi no Kisetsu: Status 405
# Failed to retrieve search page for Sugar Bunnies Chocolate!: Status 405
# Failed to retrieve search page for Taekwon Dongja Maruchi Arachi: Status 405
# Failed to retrieve search page for Tao Hua Yuan Ji: Status 405
# Failed to retrieve search page for Sumiko no Egao: Status 405
# Failed to retrieve search page for Tabidachi no Hi ni: Status 405
# Failed to retrieve search page for Stray Sheep: Poe no Chicchana Daibouken: Status 405
# Failed to retrieve search page for Spy Gekimetsu: Status 405
# Failed to retrieve search page for Tamagotchi! x Himitsukessha Taka no Tsume: Status 405
# Failed to retrieve search page for Tam Mao Phieu Luu Ky Ta: Status 405
# Failed to retrieve search page for Takemoto Denki x Peeping Life: Status 405
# Failed to retrieve search page for Suijun Genten: Status 405
# Failed to retrieve search page for Tatakae! Osper: Status 405
# Failed to retrieve search page for Sumiko: Status 405
# Failed to retrieve search page for Taiman Blues: Shimizu Naoto-hen: Status 405
# Failed to retrieve search page for Stone: Status 405
# Failed to retrieve search page for Sugar Bunnies Fleur: Status 405
# Failed to retrieve search page for Sugar Bunnies Chocolate!: Status 405
# Failed to retrieve search page for Takarajima (Movie): Status 405
# Failed to retrieve search page for Taekwon Dongja Maruchi Arachi: Status 405
# Failed to retrieve search page for Sugar Bunnies Chocolate! Specials: Status 405
# Failed to retrieve search page for Tamagotchi Honto no Hanashi: Status 405
# Failed to retrieve search page for Starlight Scramble Renai Kouhosei: Status 405
# Failed to retrieve search page for Sumiko no Egao: Status 405
# Failed to retrieve search page for Tabidachi no Hi ni: Status 405
# Failed to retrieve search page for Stray Sheep: Poe no Chicchana Daibouken: Status 405
# Failed to retrieve search page for Tabi no Kisetsu: Status 405
# Failed to retrieve search page for Tamagotchi! x Himitsukessha Taka no Tsume: Status 405
# Failed to retrieve search page for Sue Cat: Status 405
# Failed to retrieve search page for Sugata Sanshirou: Status 405
# Failed to retrieve search page for Sumiko: Status 405
# Failed to retrieve search page for Super Samchongsa: Status 405
# Failed to retrieve search page for Tabi wa Michizure Yo wa Nasake: Status 405
# Failed to retrieve search page for Tako ni Natta Okaasan: Status 405
# Failed to retrieve search page for Takarajima (Movie): Status 405
# Failed to retrieve search page for Sugar Bunnies Chocolate! Specials: Status 405
# Failed to retrieve search page for Tantei Opera Milky Holmes Movie: Gyakushuu no Milky Holmes: Status 405
# Failed to retrieve search page for Sylvanian Families Mini Gekijou: Omoigakenai Okyakusama: Status 405
# Failed to retrieve search page for Tachumaru Gekijou: Status 405
# Failed to retrieve search page for Tanuki-san Ooatari: Status 405
# Failed to retrieve search page for Tamagotchi Honto no Hanashi: Status 405
# Failed to retrieve search page for Sugata Sanshirou: Status 405
# Failed to retrieve search page for Super Samchongsa: Status 405
# Failed to retrieve search page for Tabi wa Michizure Yo wa Nasake: Status 405
# Failed to retrieve search page for Tako ni Natta Okaasan: Status 405
# Failed to retrieve search page for Taka no Tsume 8: Yoshida-kun no X-Files: Status 405
# Failed to retrieve search page for Tantei Opera Milky Holmes Movie: Gyakushuu no Milky Holmes: Status 405
# Failed to retrieve search page for Sylvanian Families Mini Gekijou: Omoigakenai Okyakusama: Status 405
# Failed to retrieve search page for Tachumaru Gekijou: Status 405
# Failed to retrieve search page for Tanuki-san Ooatari: Status 405
# Failed to retrieve search page for Suiren no Hito: Status 405
# Failed to retrieve search page for Taeng-gu &amp; Ulasyong: Status 405
# Failed to retrieve search page for Susume! Shinji-kun: Status 405
# Failed to retrieve search page for Suiren no Hito: Status 405
# Failed to retrieve search page for Taka no Tsume 8: Yoshida-kun no X-Files: Status 405
# Failed to retrieve search page for Super Titans 15: Status 405
# Failed to retrieve search page for Sugar Bunnies: Taisetsu na Tomodachi e...: Status 405
# Failed to retrieve search page for Takoyaki Mant-Man: Status 405
# Failed to retrieve search page for Spo-chan Taiketsu: Youkai Daikessen: Status 405
# Failed to retrieve search page for Takarakuji x Rope: Status 405
# Failed to retrieve search page for Suna Asobi: Status 405
# Failed to retrieve search page for Takanotsume GO: Utsukushiki Elleair Shoushuu Plus: Status 405
# Failed to retrieve search page for Spring Stranger: Status 405
# Failed to retrieve search page for Taeng-gu &amp; Ulasyong: Status 405
# Failed to retrieve search page for Sugar Bunnies: Taisetsu na Tomodachi e...: Status 405
# Failed to retrieve search page for Spo-chan Taiketsu: Youkai Daikessen: Status 405
# Failed to retrieve search page for Takoyaki Mant-Man: Status 405
# Failed to retrieve search page for Takarakuji x Rope: Status 405
# Failed to retrieve search page for Tanbai Haru, Tookaraji: Status 405
# Failed to retrieve search page for Suna Asobi: Status 405
# Failed to retrieve search page for Takanotsume GO: Utsukushiki Elleair Shoushuu Plus: Status 405
# Failed to retrieve search page for Spring Stranger: Status 405
# Failed to retrieve search page for Tanbai Haru, Tookaraji: Status 405
# Failed to retrieve search page for Teach: Status 405
# Failed to retrieve search page for Sugar Bunnies: Status 405
# Failed to retrieve search page for Teach: Status 405
# Failed to retrieve search page for Super Taromu: Status 405
# Failed to retrieve search page for Sugar Bunnies: Status 405
# Failed to retrieve search page for Super Taromu: Status 405
# Failed to retrieve search page for Taegeugsonyeon Huin Dogsuli: Status 405
# Failed to retrieve search page for Taegeugsonyeon Huin Dogsuli: Status 405
# Error fetching Tatakae!! Ramenman (Movie): . Retrying in 80 seconds...
# Error fetching Tekusuke Monogatari: . Retrying in 80 seconds...
# Error fetching Steady x Study: . Retrying in 80 seconds...
# Error fetching Tegami: . Retrying in 80 seconds...
# Error fetching Spy Penguin: . Retrying in 80 seconds...
# Error fetching Super Backkom: . Retrying in 80 seconds...
# Error fetching Tamagotchi! Miracle Friends: . Retrying in 80 seconds...
# Failed to retrieve search page for Steady x Study: Status 405
# Failed to retrieve search page for Tegami: Status 405
# Failed to retrieve search page for Tekusuke Monogatari: Status 405
# Failed to retrieve search page for Tamagotchi! Miracle Friends: Status 405
# Failed to retrieve search page for Tatakae!! Ramenman (Movie): Status 405
# Failed to retrieve search page for Spy Penguin: Status 405
# Failed to retrieve search page for Super Backkom: Status 405
# Image URLs added to the CSV file in 503.76 seconds.
